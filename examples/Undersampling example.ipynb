# %%
import numpy as np
import matplotlib.pyplot as plt
from smote_cd import dataset_generation
from smote_cd import random_undersampling

# %% [markdown]
# # Generation of the data
#
# We first generate a synthetic dataset with a well-chosen $\beta$ matrix so that the dataset will be imbalanced. For more information about the generation of the datasets, you can have a look at the notebook *Dataset generation example.ipynb*.

# %%
n_features = 2
n_classes = 2
size = 1000

betas = [[0.8, 0.8, 0.8],[-3, 0.2, 0.6]]
generated_X,generated_y,_ = dataset_generation.generate_dataset(n_features,n_classes,size,betas=betas,random_state=0)

# %%
plt.scatter(generated_X[:,0],generated_X[:,1],c=generated_y[:,0],s=10)
plt.show()

# %% [markdown]
# Almost 80% of the points are from class 0 :

# %%
sum(generated_y)
# Out:
# array([798.18324712, 201.81675288])

# %% [markdown]
# # Undersampling
#
# We undersample the majority class.

# %%
indexes_to_remove = random_undersampling(generated_y, method='majority')

# %%
y_undersampled=np.delete(generated_y,indexes_to_remove,axis=0)
X_undersampled=np.delete(generated_X,indexes_to_remove,axis=0)

# %%
plt.scatter(X_undersampled[:,0],X_undersampled[:,1],c=y_undersampled[:,0],s=10)
plt.show()

# %% [markdown]
# Now, class 0 is approximately 50% :

# %%
sum(y_undersampled)
# Out:
# array([202.6133768, 182.3866232])
